# %% [markdown]
# <a href="https://colab.research.google.com/github/jackp2733/cs417-lab1/blob/main/CS417_Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CS 417 - Lab 1: Google Colab Introduction
# 1/20/26
# This notebook demonstrates basic Python concepts including:
# - Print statements
# - Variables
# - Basic arithmetic operations
# - String formatting

# %%
# Basic print statements
print("Welcome to Google Colab!")
print("Python makes programming fun!")
# Out:
# Welcome to Google Colab!
# Python makes programming fun!

# %%
# Working with variables
favorite_food = "tacos" # Replace with your favorite food
favorite_number = 3 # Replace with your favorite number
favorite_color = "red" # Replace with your favorite color
print("My favorite food is:", favorite_food)
print("My favorite number is:", favorite_number)
print("My favorite color is:", favorite_color)
# Out:
# My favorite food is: tacos
# My favorite number is: 3
# My favorite color is: red

# %%
patriots_score = 28
texans_score = 16
combined_score = patriots_score + texans_score
print("Patriots score:", patriots_score)
print("Texans score:", texans_score)
print("Combined score:", combined_score)
# Out:
# Patriots score: 28
# Texans score: 16
# Combined score: 44
