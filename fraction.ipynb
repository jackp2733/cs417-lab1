# %% [markdown]
# <a href="https://colab.research.google.com/github/jackp2733/cs417-lab1/blob/main/fraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Fraction:
    def __init__(self,top,bottom):
        self.num=top
        self.den=bottom

f1=Fraction(5,6)
f2=Fraction(9,2)

print (f1)
print (f2)
